# %%
import modules.Metrica_IO as mio
import modules.Metrica_Viz as mviz

# %%
DATADIR = 'LaurieOnTracking-master/sample-data-master/data/'
game_id = 1

# %%
events = mio.read_event_data(DATADIR,game_id)

# %%
events = mio.to_metric_coordinates(events)

# %%
fig,ax = mviz.plot_pitch()
ax.plot( events.loc[1114]['Start X'], events.loc[1114]['Start Y'], 'ro' )
ax.annotate("", xy=events.loc[1114][['End X','End Y']], xytext=events.loc[1114][['Start X','Start Y']], alpha=0.6, arrowprops=dict(arrowstyle="->",color='r'))
# Out:
# Text(-44.519999999999996, 12.92, '')

# %%
fig,ax = mviz.plot_pitch()

# %%
mviz.plot_events( events.loc[1111:1114], indicators = ['Marker','Arrow'], annotate=True)
# Out:
# (<Figure size 864x576 with 1 Axes>, <AxesSubplot:>)

# %%
tracking_home = mio.tracking_data(DATADIR,game_id,'Home')
tracking_away = mio.tracking_data(DATADIR,game_id,'Away')
# Out:
# Reading team: home
# Reading team: away

# %%
# Convert positions from metrica units to meters 
tracking_home = mio.to_metric_coordinates(tracking_home)
tracking_away = mio.to_metric_coordinates(tracking_away)

# %%
KO_Frame = events.loc[0]['Start Frame']

# %%
fig,ax = mviz.plot_frame( tracking_home.loc[KO_Frame], tracking_away.loc[KO_Frame] )
# Out:
# D:\friends-of-tracking\modules\Metrica_Viz.py:141: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   ax.plot( team[x_columns], team[y_columns], color+'o', MarkerSize=PlayerMarkerSize, alpha=PlayerAlpha ) # plot player positions
# D:\friends-of-tracking\modules\Metrica_Viz.py:141: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   ax.plot( team[x_columns], team[y_columns], color+'o', MarkerSize=PlayerMarkerSize, alpha=PlayerAlpha ) # plot player positions
# D:\friends-of-tracking\modules\Metrica_Viz.py:149: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   ax.plot( hometeam['ball_x'], hometeam['ball_y'], 'ko', MarkerSize=6, alpha=1.0, LineWidth=0)

# %%
fig,ax = mviz.plot_events( events.loc[198:198], indicators = ['Marker','Arrow'], annotate=True )

# %%
goal_frame = events.loc[1114]['Start Frame']

# %%
start_frame = events.loc[1111]['Start Frame']

# %%
fig,ax = mviz.plot_events( tracking_home.loc[start_frame:goal_frame], indicators = ['Marker','Arrow'], figax = (fig, ax) )
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\users\hp\appdata\local\programs\python\python37\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Start X'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-36-fc890c6fea5f> in <module>
# ...

# %%
fig,ax = mviz.plot_pitch()
mviz.plot_events( goal1, indicators = ['Marker','Arrow'], figax=(fig, ax), annotate=True)
ax.plot( tracking_home['Home_10_x'].loc[start_frame:goal_frame], tracking_home['Home_10_y'].loc[start_frame:goal_frame], 'b.', MarkerSize=1)

ax.plot( tracking_home['Home_5_x'].loc[start_frame:goal_frame], tracking_home['Home_5_y'].loc[start_frame:goal_frame], 'b.', MarkerSize=1)
# Out:
# c:\users\hp\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:3: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   This is separate from the ipykernel package so we can avoid doing imports until
# c:\users\hp\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:5: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   """

# %%
events
# Out:
#       Team       Type       Subtype  Period  Start Frame  Start Time [s]  \
# 0     Away  SET PIECE      KICK OFF       1           51            2.04
# 1     Away       PASS           NaN       1           51            2.04
# 2     Away       PASS           NaN       1          146            5.84
# 3     Away       PASS           NaN       1          248            9.92
# 4     Away       PASS           NaN       1          316           12.64
# ...    ...        ...           ...     ...          ...             ...
# 1930  Away  BALL LOST  INTERCEPTION       2       140122         5604.88
# 1931  Home  CHALLENGE   AERIAL-LOST       2       140180         5607.20
# 1932  Away  CHALLENGE   AERIAL-LOST       2       140183         5607.32
# 1933  Home   RECOVERY           NaN       2       140211         5608.44
# 1934  Home   BALL OUT     CLEARANCE       2       140265         5610.60
#
#       End Frame  End Time [s]      From        To  Start X  Start Y  End X  \
# ...

# %%
tracking_home['Home_10_x'].loc[start_frame:goal_frame]
# Out:
# Frame
# 11647   -24.07684
# 11648   -23.96342
# 11649   -23.85106
# 11650   -23.73658
# 11651   -23.62210
#            ...
# 12198   -46.68664
# 12199   -46.87108
# 12200   -46.99404
# 12201   -47.21028
# 12202   -47.42652
# Name: Home_10_x, Length: 556, dtype: float64

# %%
ax.plot( tracking_home['Home_10_x'].loc[start_frame:goal_frame], tracking_home['Home_11_y'].loc[start_frame:goal_frame], 'r.', MarkerSize=1)
# Out:
# c:\users\hp\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:1: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   """Entry point for launching an IPython kernel.

# %%
fig,ax = mviz.plot_pitch()
ax.plot( tracking_home['Home_10_x'].loc[start_frame:goal_frame], tracking_home['Home_10_y'].loc[start_frame:goal_frame], 'r.', MarkerSize=1)
# Out:
# c:\users\hp\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:2: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later

# %%
goal1 = events.loc[1111:1114]
goal1_player10 = goal1[goal1['From'] == 'Player10']

# %%
goal1
# Out:
#      Team  Type         Subtype  Period  Start Frame  Start Time [s]  \
# 190  Home  PASS             NaN       1        11647          465.88
# 191  Home  PASS             NaN       1        11685          467.40
# 192  Home  PASS             NaN       1        11721          468.84
# 193  Home  PASS             NaN       1        11810          472.40
# 194  Home  PASS             NaN       1        11958          478.32
# 195  Home  PASS             NaN       1        11976          479.04
# 196  Home  PASS             NaN       1        12069          482.76
# 197  Home  PASS           CROSS       1        12180          487.20
# 198  Home  SHOT  ON TARGET-GOAL       1        12202          488.08
#
#      End Frame  End Time [s]      From        To  Start X  Start Y  End X  \
# 190      11685        467.40   Player7  Player10   -13.78    -0.68 -21.20
# 191      11703        468.12  Player10   Player5   -21.20    -0.00 -18.02
# ...

# %%
shots = events[events['Type'] == 'SHOT']
shots[shots['Subtype'].str.contains('-GOAL')]
# Out:
#       Team  Type              Subtype  Period  Start Frame  Start Time [s]  \
# 34    Home  SHOT  HEAD-ON TARGET-GOAL       1         2289           91.56
# 1114  Home  SHOT       ON TARGET-GOAL       2        90005         3600.20
# 1213  Home  SHOT       ON TARGET-GOAL       2        99032         3961.28
#
#       End Frame  End Time [s]      From   To  Start X  Start Y  End X  End Y
# 34         2309         92.36   Player9  NaN    44.52     2.04  54.06  -3.40
# 1114      90026       3601.04  Player10  NaN   -44.52    12.92 -53.00  -2.72
# 1213      99046       3961.84   Player9  NaN   -50.88    -2.72 -54.06  -0.68

# %%
events.loc[1100:1114]
# Out:
#       Team       Type             Subtype  Period  Start Frame  \
# 1100  Home  SET PIECE           FREE KICK       2        89270
# 1101  Home       PASS                 NaN       2        89270
# 1102  Home       PASS                 NaN       2        89349
# 1103  Home       PASS                 NaN       2        89486
# 1104  Home       PASS                 NaN       2        89622
# 1105  Home       PASS                 NaN       2        89691
# 1106  Home       PASS                 NaN       2        89726
# 1107  Home  BALL LOST  CROSS-INTERCEPTION       2        89802
# 1108  Away   RECOVERY        INTERCEPTION       2        89832
# 1109  Away  BALL LOST      HEAD-CLEARANCE       2        89832
# 1110  Home   RECOVERY                 NaN       2        89875
# 1111  Home       PASS                HEAD       2        89875
# 1112  Home       PASS                 NaN       2        89955
# 1113  Home       PASS                 NaN       2        89978
# ...
